# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasmaskar09/BML/blob/main/Skill_4_normalizing_sca_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
file_path = "/content/Diabetes.csv"
df = pd.read_csv(file_path)

# Apply Min-Max Scaling (normalization) to scale numerical features between 0 and 1
scaler = MinMaxScaler()
df[df.columns] = scaler.fit_transform(df)

# Display first few rows of the normalized dataset
df.head()
# Out:
#    pregnancies   glucose  diastolic   triceps   insulin       bmi       dpf  \
# 0     0.352941  0.743719   0.590164  0.353535  0.000000  0.500745  0.234415
# 1     0.058824  0.427136   0.540984  0.292929  0.000000  0.396423  0.116567
# 2     0.470588  0.919598   0.524590  0.000000  0.000000  0.347243  0.253629
# 3     0.058824  0.447236   0.540984  0.232323  0.111111  0.418778  0.038002
# 4     0.000000  0.688442   0.327869  0.353535  0.198582  0.642325  0.943638
#
#         age  diabetes
# 0  0.483333       1.0
# 1  0.166667       0.0
# 2  0.183333       1.0
# 3  0.000000       0.0
# 4  0.200000       1.0
