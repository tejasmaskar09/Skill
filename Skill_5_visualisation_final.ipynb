# %% [markdown]
# <a href="https://colab.research.google.com/github/tejasmaskar09/BML/blob/main/Skill_5_visualisation_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

file_path = "/content/Diabetes.csv"
df = pd.read_csv(file_path)

# Set style for better visuals
sns.set(style="whitegrid")

# 1. Histogram for feature distribution
df.hist(figsize=(12, 8), bins=20, edgecolor="black")
plt.suptitle("Feature Distributions", fontsize=16)
plt.show()

# %%
# 2. Boxplot to detect outliers
plt.figure(figsize=(12, 6))
sns.boxplot(data=df)
plt.xticks(rotation=45)
plt.title("Boxplot for Outlier Detection")
plt.show()

# %%
# 3. Correlation heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
# 4. Pairplot for relationships between features
sns.pairplot(df, hue="diabetes", diag_kind="kde", corner=True)
plt.show()
